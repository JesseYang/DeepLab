# %%
from reader import *
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# WARNING:tensorflow:From /home/user/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
ds = Data('voc_val.txt', shuffle=False, flip=False, random_crop=False, test_set=True, save_img=True)

# %%
ds.reset_state()

# %%
g = ds.get_data()

# %%
dp = next(g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f92948f60135> in <module>()
# ----> 1 dp = next(g)
#
# /home/user/tj/deeplabv3+_tensorpack/reader.py in get_data(self)
#     142         label = np.expand_dims(label, axis=-1)
#     143
# --> 144         return [image.astype(np.float32), label.astype(np.float32)]
#     145
#     146     def get_data(self):
#
# /home/user/tj/deeplabv3+_tensorpack/reader.py in generate_sample(self, idx)
#      90             # mean_pixel = np.reshape(cfg.mean_pixel, [1, 1, 3])
#      91             image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=cfg.mean_pixel)
# ---> 92
#      93             if label is not None:
#      94                 label = cv2.copyMakeBorder(label, top, bottom, left, right, cv2.BORDER_CONSTANT, value=cfg.ignore_label)
#
# ValueError: operands could not be broadcast together with shapes (500,375) (3,)

# %%
len(dp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-87e91cdf7937> in <module>()
# ----> 1 len(dp)
#
# NameError: name 'dp' is not defined

# %%
dp[1].shape
# Out:
# (513, 513, 1)

# %%
plt.imshow(dp[0])

# %%
plt.imshow(dp[1][:,:,0], cmap='gray')
